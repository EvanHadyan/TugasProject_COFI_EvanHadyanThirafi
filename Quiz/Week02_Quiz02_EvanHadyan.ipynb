# %% [markdown]
# ## soal 1
#
# Pt.Cofi sedang melakukan sebuah project, senior Data Scientist telah melakukan clustering menggunakan model K-means. setelah di clusering kalian diminta tolong oleh Senior kalian untuk melanjutkan project ini. Anda sebagai Data Junior Scientist diminta untuk melakukan eksplore terhadap data yang ada untuk menentukan arti dari tiap tiap cluster yang ada.
# berikut adalah keterangan dari tiap column
#
# https://search.r-project.org/CRAN/refmans/HSAUR3/html/USairpollution.html
#
# note:
# 1. Kalian dibebaskan untuk melakukan visualisasi apapun, serta menjabarkan apa saja yang anda temukan.
# 2. Tujuan akhir dari soal ini adalah pengelompokan dari tiap cluster yang ada.
# 3. Disarankan juga mencari informasi dari luar (browsing google).

# %%
import pandas as pd
import numpy as np

df = pd.read_csv('USairpollution_quiz2.csv')
df.head(3)
# Out:
#           City  SO2  temp  manu  popul  wind  precip  predays  clusters
# 0       Albany   46  47.6    44    116   8.8   33.36      135         1
# 1  Albuquerque   11  56.8    46    244   8.9    7.77       58         0
# 2      Atlanta   24  61.5   368    497   9.1   48.34      115         3

# %%
df['clusters'].unique()
# Out:
# array([1, 0, 3, 4, 2], dtype=int64)

# %%
df.describe()
# Out:
#               SO2       temp         manu        popul       wind     precip  \
# count   41.000000  41.000000    41.000000    41.000000  41.000000  41.000000
# mean    30.048780  55.763415   463.097561   608.609756   9.443902  36.769024
# std     23.472272   7.227716   563.473948   579.113023   1.428644  11.771550
# min      8.000000  43.500000    35.000000    71.000000   6.000000   7.050000
# 25%     13.000000  50.600000   181.000000   299.000000   8.700000  30.960000
# 50%     26.000000  54.600000   347.000000   515.000000   9.300000  38.740000
# 75%     35.000000  59.300000   462.000000   717.000000  10.600000  43.110000
# max    110.000000  75.500000  3344.000000  3369.000000  12.700000  59.800000
#
#           predays   clusters
# count   41.000000  41.000000
# mean   113.902439   1.926829
# std     26.506419   1.367301
# min     36.000000   0.000000
# 25%    103.000000   1.000000
# 50%    115.000000   1.000000
# 75%    128.000000   3.000000
# max    166.000000   4.000000

# %%
df4 = df[df['clusters']==4]
df3 = df[df['clusters']==3]
df2 = df[df['clusters']==2]
df1 = df[df['clusters']==1]
df0 = df[df['clusters']==0]

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
df4.head(3)
# Out:
#            City  SO2  temp  manu  popul  wind  precip  predays  clusters
# 4       Buffalo   11  47.1   391    463  12.4   36.11      166         4
# 12   Des Moines   17  49.0   104    201  11.2   30.85      103         4
# 18  Kansas City   14  54.5   381    507  10.0   37.00       99         4

# %%
df3.head(3)
# Out:
#        City  SO2  temp  manu  popul  wind  precip  predays  clusters
# 2   Atlanta   24  61.5   368    497   9.1   48.34      115         3
# 10   Dallas    9  66.2   641    844  10.9   35.94       78         3
# 15  Houston   10  68.9   721   1233  10.8   48.19      103         3

# %%
df2.head(3)
# Out:
#             City  SO2  temp  manu  popul  wind  precip  predays  clusters
# 6        Chicago  110  50.6  3344   3369  10.4   34.44      122         2
# 29  Philadelphia   69  54.6  1692   1950   9.6   39.93      115         2

# %%
df1.head(3)
# Out:
#          City  SO2  temp  manu  popul  wind  precip  predays  clusters
# 0      Albany   46  47.6    44    116   8.8   33.36      135         1
# 3   Baltimore   47  55.0   625    905   9.6   41.31      111         1
# 5  Charleston   31  55.2    35     71   6.5   40.75      148         1

# %%
df0.head(3)
# Out:
#            City  SO2  temp  manu  popul  wind  precip  predays  clusters
# 1   Albuquerque   11  56.8    46    244   8.9    7.77       58         0
# 11       Denver   17  51.9   454    515   9.0   12.95       86         0
# 30      Phoenix   10  70.3   213    582   6.0    7.05       36         0

# %%
df4['City'].unique()
# Out:
# array(['Buffalo', 'Des Moines', 'Kansas City', 'Milwaukee', 'Minneapolis',
#        'Omaha', 'Wichita'], dtype=object)

# %%
df3['City'].unique()
# Out:
# array(['Atlanta', 'Dallas', 'Houston', 'Jacksonville', 'Little Rock',
#        'Memphis', 'Miami', 'Nashville', 'New Orleans', 'Norfolk'],
#       dtype=object)

# %%
df2['City'].unique()
# Out:
# array(['Chicago', 'Philadelphia'], dtype=object)

# %%
df1['City'].unique()
# Out:
# array(['Albany', 'Baltimore', 'Charleston', 'Cincinnati', 'Cleveland',
#        'Columbus', 'Detroit', 'Hartford', 'Indianapolis', 'Louisville',
#        'Pittsburgh', 'Providence', 'Richmond', 'Seattle', 'St. Louis',
#        'Washington', 'Wilmington'], dtype=object)

# %%
df0['City'].unique()
# Out:
# array(['Albuquerque', 'Denver', 'Phoenix', 'Salt Lake City',
#        'San Francisco'], dtype=object)

# %% [markdown]
# ### SO2 VS CITY

# %%
so2_df4 = df4.groupby('City')[['SO2']].median().reset_index().sort_values(by=['SO2'], ascending=False)

# %%
so2_df4
# Out:
#           City   SO2
# 4  Minneapolis  29.0
# 1   Des Moines  17.0
# 3    Milwaukee  16.0
# 2  Kansas City  14.0
# 5        Omaha  14.0
# 0      Buffalo  11.0
# 6      Wichita   8.0

# %%
#  SO2

x=range(len(so2_10_top_df4['City']))
plt.figure(figsize=(12,5))
plt.bar(x,so2_10_top_df4['SO2'])
plt.xticks(x,so2_10_top_df4['City'])
plt.xlabel('negara')
plt.ylabel('rata rata so2')
plt.title('SO2 pada cluster 4')
plt.show()

# %%
so2_df3 = df3.groupby('City')[['SO2']].median().reset_index().sort_values(by=['SO2'], ascending=False)

# %%
so2_df3
# Out:
#            City   SO2
# 9       Norfolk  31.0
# 0       Atlanta  24.0
# 7     Nashville  18.0
# 3  Jacksonville  14.0
# 4   Little Rock  13.0
# 2       Houston  10.0
# 5       Memphis  10.0
# 6         Miami  10.0
# 1        Dallas   9.0
# 8   New Orleans   9.0

# %%
x=range(len(so2_df3['City']))
plt.figure(figsize=(12,5))
plt.bar(x,so2_df3['SO2'])
plt.xticks(x,so2_df3['City'])
plt.xlabel('negara')
plt.ylabel('rata rata temp')
plt.title('SO2 pada cluster 3')
plt.show()

# %%
so2_df2 = df2.groupby('City')[['SO2']].median().reset_index().sort_values(by=['SO2'], ascending=False)
so2_df2
# Out:
#            City    SO2
# 0       Chicago  110.0
# 1  Philadelphia   69.0

# %%
so2_df1 = df1.groupby('City')[['SO2']].median().reset_index().sort_values(by=['SO2'], ascending=False)
so2_df1.head(3)
# Out:
#           City   SO2
# 11  Providence  94.0
# 4    Cleveland  65.0
# 10  Pittsburgh  61.0

# %%
x=range(len(so2_df1['City']))
plt.figure(figsize=(21,5))
plt.bar(x,so2_df1['SO2'])
plt.xticks(x,so2_df1['City'])
plt.xlabel('negara')
plt.ylabel('rata rata temp')
plt.title('SO2 pada cluster 1')
plt.show()

# %%
so2_df0 = df0.groupby('City')[['SO2']].median().reset_index().sort_values(by=['SO2'], ascending=False)
so2_df0
# Out:
#              City   SO2
# 3  Salt Lake City  28.0
# 1          Denver  17.0
# 4   San Francisco  12.0
# 0     Albuquerque  11.0
# 2         Phoenix  10.0

# %%
x=range(len(so2_df0['City']))
plt.figure(figsize=(21,5))
plt.bar(x,so2_df0['SO2'])
plt.xticks(x,so2_df0['City'])
plt.xlabel('negara')
plt.ylabel('rata rata temp')
plt.title('SO2 pada cluster 0')
plt.show()

# %% [markdown]
# #### Insight
# cluster 2 & 1 memiliki tingkat so2 yang lumayan tinggi (chicago=110 & philadelphia=69) untuk cluster 2 dan (providence=94, cleveland=65, pittsburgh=61) sedangkan cluster 0,3,4 memiliki tingkat so2 yang sedang (<35)

# %% [markdown]
# ### city vs temp

# %%
temp_df4 = df4.groupby('City')[['temp']].mean().reset_index().sort_values(by=['temp'], ascending=False)
temp_df4
# Out:
#           City  temp
# 6      Wichita  56.6
# 2  Kansas City  54.5
# 5        Omaha  51.5
# 1   Des Moines  49.0
# 0      Buffalo  47.1
# 3    Milwaukee  45.7
# 4  Minneapolis  43.5

# %%
x=range(len(temp_df4['City']))
plt.figure(figsize=(21,5))
plt.bar(x,temp_df4['temp'])
plt.xticks(x,temp_df4['City'])
plt.xlabel('negara')
plt.ylabel('rata rata temp')
plt.title('temp pada cluster 4')
plt.show()

# %%
temp_df3 = df3.groupby('City')[['temp']].mean().reset_index().sort_values(by=['temp'], ascending=False)
temp_df3
# Out:
#            City  temp
# 6         Miami  75.5
# 2       Houston  68.9
# 3  Jacksonville  68.4
# 8   New Orleans  68.3
# 1        Dallas  66.2
# 5       Memphis  61.6
# 0       Atlanta  61.5
# 4   Little Rock  61.0
# 7     Nashville  59.4
# 9       Norfolk  59.3

# %%
x=range(len(temp_df3['City']))
plt.figure(figsize=(21,5))
plt.bar(x,temp_df3['temp'])
plt.xticks(x,temp_df3['City'])
plt.xlabel('negara')
plt.ylabel('rata rata temp')
plt.title('temp pada cluster 3')
plt.show()

# %%
temp_df2 = df2.groupby('City')[['temp']].mean().reset_index().sort_values(by=['temp'], ascending=False)
temp_df2
# Out:
#            City  temp
# 1  Philadelphia  54.6
# 0       Chicago  50.6

# %%
temp_df1 = df1.groupby('City')[['temp']].mean().reset_index().sort_values(by=['temp'], ascending=False)
temp_df1
# Out:
#             City  temp
# 12      Richmond  57.8
# 15    Washington  57.3
# 14     St. Louis  55.9
# 9     Louisville  55.6
# 2     Charleston  55.2
# 1      Baltimore  55.0
# 16    Wilmington  54.0
# 3     Cincinnati  54.0
# 8   Indianapolis  52.3
# 5       Columbus  51.5
# 13       Seattle  51.1
# 10    Pittsburgh  50.4
# 11    Providence  50.0
# 6        Detroit  49.9
# 4      Cleveland  49.7
# 7       Hartford  49.1
# 0         Albany  47.6

# %%
x=range(len(temp_df1['City']))
plt.figure(figsize=(21,5))
plt.bar(x,temp_df1['temp'])
plt.xticks(x,temp_df1['City'])
plt.xlabel('negara')
plt.ylabel('rata rata temp')
plt.title('temp pada cluster 1')
plt.show()

# %%
temp_df0 = df0.groupby('City')[['temp']].mean().reset_index().sort_values(by=['temp'], ascending=False)
temp_df0
# Out:
#              City  temp
# 2         Phoenix  70.3
# 0     Albuquerque  56.8
# 4   San Francisco  56.7
# 1          Denver  51.9
# 3  Salt Lake City  51.0

# %%
x=range(len(temp_df0['City']))
plt.figure(figsize=(21,5))
plt.bar(x,temp_df0['temp'])
plt.xticks(x,temp_df0['City'])
plt.xlabel('negara')
plt.ylabel('rata rata temp')
plt.title('temp pada cluster 0')
plt.show()

# %% [markdown]
# #### Insight
# ditinjau dari data suhu, antara cluster 4 hingga 0 memiliki kemiripan nilai sama, sehingga cluster tidak di dasarkan pada data suhu

# %% [markdown]
# ### Popul vs city

# %%
pop_df4 = df4.groupby('City')[['popul']].median().reset_index().sort_values(by=['popul'], ascending=False)
pop_df4
# Out:
#           City  popul
# 4  Minneapolis  744.0
# 3    Milwaukee  717.0
# 2  Kansas City  507.0
# 0      Buffalo  463.0
# 5        Omaha  347.0
# 6      Wichita  277.0
# 1   Des Moines  201.0

# %%
x=range(len(pop_df4['City']))
plt.figure(figsize=(21,5))
plt.bar(x,pop_df4['popul'])
plt.xticks(x,pop_df4['City'])
plt.xlabel('negara')
plt.ylabel('rata rata populasi')
plt.title('populasi pada cluster 4')
plt.show()

# %%
pop_df3 = df3.groupby('City')[['popul']].median().reset_index().sort_values(by=['popul'], ascending=False)
pop_df3
# Out:
#            City   popul
# 2       Houston  1233.0
# 1        Dallas   844.0
# 5       Memphis   624.0
# 3  Jacksonville   529.0
# 0       Atlanta   497.0
# 7     Nashville   448.0
# 8   New Orleans   361.0
# 6         Miami   335.0
# 9       Norfolk   308.0
# 4   Little Rock   132.0

# %%
x=range(len(pop_df3['City']))
plt.figure(figsize=(21,5))
plt.bar(x,pop_df3['popul'])
plt.xticks(x,pop_df3['City'])
plt.xlabel('negara')
plt.ylabel('rata rata populasi')
plt.title('populasi pada cluster 3')
plt.show()

# %%
pop_df2 = df2.groupby('City')[['popul']].median().reset_index().sort_values(by=['popul'], ascending=False)
pop_df2
# Out:
#            City   popul
# 0       Chicago  3369.0
# 1  Philadelphia  1950.0

# %%
x=range(len(pop_df2['City']))
plt.figure(figsize=(21,5))
plt.bar(x,pop_df2['popul'])
plt.xticks(x,pop_df2['City'])
plt.xlabel('negara')
plt.ylabel('rata rata populasi')
plt.title('populasi pada cluster 2')
plt.show()

# %%
pop_df1 = df1.groupby('City')[['popul']].median().reset_index().sort_values(by=['popul'], ascending=False)
pop_df1
# Out:
#             City   popul
# 6        Detroit  1513.0
# 1      Baltimore   905.0
# 15    Washington   757.0
# 4      Cleveland   751.0
# 8   Indianapolis   746.0
# 14     St. Louis   622.0
# 9     Louisville   593.0
# 5       Columbus   540.0
# 13       Seattle   531.0
# 10    Pittsburgh   520.0
# 3     Cincinnati   453.0
# 12      Richmond   299.0
# 11    Providence   179.0
# 7       Hartford   158.0
# 0         Albany   116.0
# 16    Wilmington    80.0
# 2     Charleston    71.0

# %%
x=range(len(pop_df1['City']))
plt.figure(figsize=(21,5))
plt.bar(x,pop_df1['popul'])
plt.xticks(x,pop_df1['City'])
plt.xlabel('negara')
plt.ylabel('rata rata populasi')
plt.title('populasi pada cluster 1')
plt.show()

# %%
pop_df0 = df0.groupby('City')[['popul']].median().reset_index().sort_values(by=['popul'], ascending=False)
pop_df0
# Out:
#              City  popul
# 4   San Francisco  716.0
# 2         Phoenix  582.0
# 1          Denver  515.0
# 0     Albuquerque  244.0
# 3  Salt Lake City  176.0

# %%
x=range(len(pop_df0['City']))
plt.figure(figsize=(21,5))
plt.bar(x,pop_df0['popul'])
plt.xticks(x,pop_df0['City'])
plt.xlabel('negara')
plt.ylabel('rata rata populasi')
plt.title('populasi pada cluster 0')
plt.show()

# %% [markdown]
# #### Insight
# cluster 2 memiliki populasi yang palig tinggi dibandingkan cluster lainya. untuk cluster lainya, rata-rata populasi dinilai mirip untuk masing masing kota, meskipun begitu kota detroit dan houston pada cluster 1 memiliki populasi banyak sejumlah 1513 & 1233 manusia. Pada cluster 2 tingkat S02 tinggi karena tingkat populasi yang banyak

# %% [markdown]
# ### City vs Precip

# %%
pr_df4 = df4.groupby('City')[['precip']].mean().reset_index().sort_values(by=['precip'], ascending=False)
pr_df4
# Out:
#           City  precip
# 2  Kansas City   37.00
# 0      Buffalo   36.11
# 1   Des Moines   30.85
# 6      Wichita   30.58
# 5        Omaha   30.18
# 3    Milwaukee   29.07
# 4  Minneapolis   25.94

# %%
x=range(len(pr_df4['City']))
plt.figure(figsize=(21,5))
plt.bar(x,pr_df4['precip'])
plt.xticks(x,pr_df4['City'])
plt.xlabel('negara')
plt.ylabel('rata rata precipitasi')
plt.title('precipitasi pada cluster 4')
plt.show()

# %%
pr_df3 = df3.groupby('City')[['precip']].mean().reset_index().sort_values(by=['precip'], ascending=False)
pr_df3
# Out:
#            City  precip
# 6         Miami   59.80
# 8   New Orleans   56.77
# 3  Jacksonville   54.47
# 5       Memphis   49.10
# 4   Little Rock   48.52
# 0       Atlanta   48.34
# 2       Houston   48.19
# 7     Nashville   46.00
# 9       Norfolk   44.68
# 1        Dallas   35.94

# %%
x=range(len(pr_df3['City']))
plt.figure(figsize=(21,5))
plt.bar(x,pr_df3['precip'])
plt.xticks(x,pr_df3['City'])
plt.xlabel('negara')
plt.ylabel('rata rata precipitasi')
plt.title('precipitasi pada cluster 3')
plt.show()

# %%
pr_df2 = df2.groupby('City')[['precip']].mean().reset_index().sort_values(by=['precip'], ascending=False)
pr_df2
# Out:
#            City  precip
# 1  Philadelphia   39.93
# 0       Chicago   34.44

# %%
pr_df1 = df1.groupby('City')[['precip']].mean().reset_index().sort_values(by=['precip'], ascending=False)
pr_df1
# Out:
#             City  precip
# 7       Hartford   43.37
# 9     Louisville   43.11
# 11    Providence   42.75
# 12      Richmond   42.59
# 1      Baltimore   41.31
# 2     Charleston   40.75
# 16    Wilmington   40.25
# 3     Cincinnati   39.04
# 15    Washington   38.89
# 13       Seattle   38.79
# 8   Indianapolis   38.74
# 5       Columbus   37.01
# 10    Pittsburgh   36.22
# 14     St. Louis   35.89
# 4      Cleveland   34.99
# 0         Albany   33.36
# 6        Detroit   30.96

# %%
x=range(len(pr_df1['City']))
plt.figure(figsize=(21,5))
plt.bar(x,pr_df1['precip'])
plt.xticks(x,pr_df1['City'])
plt.xlabel('negara')
plt.ylabel('rata rata precipitasi')
plt.title('precipitasi pada cluster 1')
plt.show()

# %%
pr_df0 = df0.groupby('City')[['precip']].mean().reset_index().sort_values(by=['precip'], ascending=False)
pr_df0
# Out:
#              City  precip
# 4   San Francisco   20.66
# 3  Salt Lake City   15.17
# 1          Denver   12.95
# 0     Albuquerque    7.77
# 2         Phoenix    7.05

# %%
x=range(len(pr_df0['City']))
plt.figure(figsize=(21,5))
plt.bar(x,pr_df0['precip'])
plt.xticks(x,pr_df0['City'])
plt.xlabel('negara')
plt.ylabel('rata rata precipitasi')
plt.title('precipitasi pada cluster 0')
plt.show()

# %% [markdown]
# #### Insight
# Pada cluster 0 memiliki tingkat presipitasi yang rendah dibandingkan dengan cluster lainya. sedangkan untuk cluster 3 terdapat beberapa kota dengan presipitasi tinggi > 50 adalah miami, jacksonvile dan new orleans dan hal ini adalah hal wajar karena wilayah tersebut berada di tenggara dimana wilayah tenggara amerika beriklim tropis sehingga curah hujan tinggi. Kemungkinan presipitasi tidak berhubungan langsung dengan S02, artinya s02 masih dalam bentuk gas dan belum mengalami proses presipitasinya

# %% [markdown]
# ### Manu vs City

# %%
man_df4 = df4.groupby('City')[['manu']].median().reset_index().sort_values(by=['manu'], ascending=False)
man_df4
# Out:
#           City   manu
# 4  Minneapolis  699.0
# 3    Milwaukee  569.0
# 0      Buffalo  391.0
# 2  Kansas City  381.0
# 5        Omaha  181.0
# 6      Wichita  125.0
# 1   Des Moines  104.0

# %%
x=range(len(man_df4['City']))
plt.figure(figsize=(21,5))
plt.bar(x,man_df4['manu'])
plt.xticks(x,man_df4['City'])
plt.xlabel('negara')
plt.ylabel('rata rata manufaktur')
plt.title('manufaktur pada cluster 4')
plt.show()

# %%
man_df3 = df3.groupby('City')[['manu']].median().reset_index().sort_values(by=['manu'], ascending=False)
man_df3
# Out:
#            City   manu
# 2       Houston  721.0
# 1        Dallas  641.0
# 0       Atlanta  368.0
# 5       Memphis  337.0
# 7     Nashville  275.0
# 6         Miami  207.0
# 8   New Orleans  204.0
# 3  Jacksonville  136.0
# 9       Norfolk   96.0
# 4   Little Rock   91.0

# %%
x=range(len(man_df3['City']))
plt.figure(figsize=(21,5))
plt.bar(x,man_df3['manu'])
plt.xticks(x,man_df3['City'])
plt.xlabel('negara')
plt.ylabel('rata rata manufaktur')
plt.title('manufaktur pada cluster 3')
plt.show()

# %%
man_df2 = df2.groupby('City')[['manu']].median().reset_index().sort_values(by=['manu'], ascending=False)
man_df2
# Out:
#            City    manu
# 0       Chicago  3344.0
# 1  Philadelphia  1692.0

# %%
x=range(len(man_df2['City']))
plt.figure(figsize=(21,5))
plt.bar(x,man_df2['manu'])
plt.xticks(x,man_df2['City'])
plt.xlabel('negara')
plt.ylabel('rata rata manufaktur')
plt.title('manufaktur pada cluster 2')
plt.show()

# %%
man_df1 = df1.groupby('City')[['manu']].median().reset_index().sort_values(by=['manu'], ascending=False)
man_df1
# Out:
#             City    manu
# 6        Detroit  1064.0
# 4      Cleveland  1007.0
# 14     St. Louis   775.0
# 1      Baltimore   625.0
# 3     Cincinnati   462.0
# 15    Washington   434.0
# 7       Hartford   412.0
# 13       Seattle   379.0
# 8   Indianapolis   361.0
# 10    Pittsburgh   347.0
# 11    Providence   343.0
# 9     Louisville   291.0
# 5       Columbus   266.0
# 12      Richmond   197.0
# 16    Wilmington    80.0
# 0         Albany    44.0
# 2     Charleston    35.0

# %%
x=range(len(man_df1['City']))
plt.figure(figsize=(21,5))
plt.bar(x,man_df1['manu'])
plt.xticks(x,man_df1['City'])
plt.xlabel('negara')
plt.ylabel('rata rata manufaktur')
plt.title('manufaktur pada cluster 1')
plt.show()

# %%
man_df0 = df0.groupby('City')[['manu']].median().reset_index().sort_values(by=['manu'], ascending=False)
man_df0
# Out:
#              City   manu
# 1          Denver  454.0
# 4   San Francisco  453.0
# 2         Phoenix  213.0
# 3  Salt Lake City  137.0
# 0     Albuquerque   46.0

# %%
x=range(len(man_df0['City']))
plt.figure(figsize=(21,5))
plt.bar(x,man_df0['manu'])
plt.xticks(x,man_df0['City'])
plt.xlabel('negara')
plt.ylabel('rata rata manufaktur')
plt.title('manufaktur pada cluster 0')
plt.show()

# %% [markdown]
# #### Insight
# terlihat kota kota pada cluster 2 memiliki total perusahaan manufaktur yang tinggi yaitu chicago 3344 perusahaan dan philadelphia dengan 1692 perusahaan manufaktur dan untuk cluster lainya terlihat sama. meskipun demikian pada cluster 1(detroit & cleveland) memiliki jumlah manufaktur tinggi yaitu 1064 dan 1007. oleh karna itu disimpulkan cluster 2 memilik tingkat s02 banyak disebabkan oleh populasi tinggi dan jumlah perusahaan manufaktur yang tinggi

# %%
df.columns
# Out:
# Index(['City', 'SO2', 'temp', 'manu', 'popul', 'wind', 'precip', 'predays',
#        'clusters'],
#       dtype='object')

# %%
#SO2 VS WIND
plt.scatter(df['SO2'],df['wind'])
plt.title('SO2 VS WIND')
plt.xlabel('SO2')
plt.ylabel('Wind')
plt.show()

# %% [markdown]
# antara SO2 dengan wind tidak ada hubungan

# %%
#SO2 VS WIND
plt.scatter(df['SO2'],df['predays'])
plt.title('SO2 VS Predays')
plt.xlabel('SO2')
plt.ylabel('Predays')
plt.show()

# %% [markdown]
# #### Insight
# 1. Untuk S02 dengan range 0-20, nilai predays memiliki range luas sekitar(20-160) sehingga SO2 dengan range tersebut tidak dapat disimpulkan
# 2. untuk SO2 dengan range 20-60, nilai predays memiliki range sekitar (100-150 ) sehingga dengan SO2 dengan range tersebut menghasilkan tingkat presipitasi/hari sebesar 100-150
# 3. untuk SO2 dengan range > 60, nilai predays memiliki range kurang lebih 120.
# 4. sehingga disimpulkan untuk SO2 >=20 tingkat presipitasi/hari berada di kisaran 120-130

# %%
#Manu VS Popu
plt.scatter(df['manu'],df['popul'])
plt.title('manu VS popul')
plt.xlabel('manu')
plt.ylabel('popul')
plt.show()

# %% [markdown]
# 1. hubungan antara manufaktur dengan populasi adalah positif dimana semakin besar populasi maka akan semakin besar jumlah perusahaan manufaktur

# %% [markdown]
# ### Kesimpulan
# Cluster 2 adalah cluster yang menyumbang gas S02 terbanyak di USA yang diakibatkan leh populasi dan manufaktur. hal ini erl menjadi perhatian pemerintah USA agar wilayah tersebut dapat mengurangi tingkat S02
